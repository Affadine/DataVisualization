# %%
import pandas as pd
import json
import requests
import bs4
import csv

from geopy.geocoders import Nominatim
import os.path
from os import path

# initialize Nominatim API  
geolocator = Nominatim(user_agent="geoapiExercises")

# %%
""" Analyse de la page HTML atlashymenoptera.net pour récupérer les liens de toutes les sources de données pour les différentes espèces """

def get_all_data_sources():
    # html page bombus dataset
    page_url = 'http://www.atlashymenoptera.net/page.aspx?id=169'
    page_text = requests.get(page_url).text
    soup = bs4.BeautifulSoup(page_text, 'html.parser')
    
    data_sources = []

    # Analyse des éléments de DOM ayant la classe mt-3
    for row in soup.find_all(class_='mt-3'):
        # Le nom de l'espèce est contenu dans l'élément de classe nomtaxon
        specie_name = row.find(class_='nomtaxon')
        if specie_name is None: continue
        # Le lien vers la source de données est contenu dans un sous-élements <a> du sous-éléement de classe col-lg-2
        link = row.find(class_='col-lg-2').find('a', text='Download dataset')
        if link is None: continue
        # Enlever les cactères blancs sur le nom de l'espèce
        specie_name = specie_name.text.strip()
        # Récupération des liens vers les images : ils sont contenus dans des sous-éléments de classe mb-3
        next_row = row.findNext(class_='mb-3').find_all('img')
        imgs = [nr.get('src') for nr in next_row]
        # Lien de sources rattachée à une espèce (identifiant espèce + nom de l'espèce + lien images + liens CSV )
        data_sources.append({
            'link': link.get('href'),
            'imgs': imgs,
            'name': specie_name,
            'id': len(data_sources) + 1
        })

    return data_sources

# %%
"""  # Affichage de la répartition par année (pour debug) """
def displayContentByYear(cleaned_dataset):
    testByYear = {}
    print(testByYear.keys())
    for row in cleaned_dataset:
        year1 = row[0] + "#" + row[3]
        year1 = row[0]
        #print("year1 : ", year1)
        if(year1 in testByYear.keys()):
            testByYear[year1]+= 1
        else:
            testByYear[year1] = 1
        #print(row)
    testByYear2 = sorted(testByYear.items(), key=lambda kv: -1*kv[1])
    print(testByYear2)


def fetch_all_dataset(data_sources):
    # données de l'ensemble des espèces
    cleaned_dataset = []
    # Parccourrir les liens que l'on a sur les différentes espèces
    for source in data_sources:
        if(1*source['id']==999994):
            continue
        server = 'http://www.atlashymenoptera.net/'
        # Récupérer le lien du fichier csv de la prochaine espèce
        dataset_url = server + source['link']
        #print("dataset_url for specie ", source['id']," : ",  dataset_url)
        # Charger le fichier csv de la prochaine espèce
        dataset = pd.read_csv(dataset_url, delimiter='\t', skiprows=2)
        dataset = dataset.drop(['Authors', 'Pub_year', 'Source'], axis=1)
        # Récupérer les données de ce CSV et les ajouter aux données de l'ensemble des espèces 
        cleaned_dataset += clean_dataset(dataset, source['id'])
        # Svg intérmédiaire
        #save_position_countries()
        print('------ finished', source['name'], 'id', source['id'], '---------')

    #displayContentByYear(cleaned_dataset)
    return pd.DataFrame(cleaned_dataset, columns=['Year', 'Latitude', 'Longitude', 'SpecieId', 'Country', 'Frequency'])

# %%
""" Vérifie si le format de l'année est correct ou non """
def invalide_year(data):    
    year=data[0]
    if(isinstance(year, float)):
        # Nombre déjà au foramt décimale (éviter un appel à strip() qui renvoie une exception)
        # Vérifier que la partie décimale est nulle
        yearInt = int(year)
        #print("invalide_year isflotat ", data, (yearInt  == year))
        #return (yearInt  == year) and yearInt > 0
    else :
        # Supprimer les espaces
        year2 = year.strip() 
        if year2 == '': return True
        if not str.isdigit(year2): return True
        yearInt = int(year2)
    # L'année doit être comprise entre 1800 et 2100
    if(yearInt>2100 or yearInt<1800): return True
    return False


def load_position_countries():
    mapPositionCountries = {}
    filename = 'pos_countries.csv'
    if(path.exists(filename)):
        with open(filename, newline='') as csvfile:
            spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
            for row in spamreader:
                #rowData = row.split(",")
                #print(row, len(row))
                if(len(row)>=2 and (row[0]!="Latitude")):
                    pos = str(row[0]) + ',' + str(row[1])
                    if(row[2]!=''):
                        mapPositionCountries[pos] = (row[2]).strip()
            csvfile.close()            
            print("load_position_countries map size = ", len(mapPositionCountries))
    return mapPositionCountries
""" """

def save_position_countries():
    rows = []
    for position in mapPositionCountries:
        item = position.split(',')       
        country = mapPositionCountries[position]
        item.append(country)
        rows.append(item)
        #print("save_position_countries", position, country, item )
    print("save_position_countries map size = ", len(mapPositionCountries) )
    dataset = pd.DataFrame(rows, columns=['Latitude', 'Longitude', 'Country'])
    dataset.to_csv('pos_countries.csv', index=False)


def get_country(row):    
    #print("get_country begin", row, mapPositionCountries)
    pos = str(row[1]) + ',' + str(row[2])        
    if(not pos in mapPositionCountries):
        locations = geolocator.reverse(pos, language='en')
        if(locations!=None):
            try:
                country  = locations.raw['address']['country']
                print("get_country", pos, country)
                mapPositionCountries[pos] = country
                if(len(mapPositionCountries) % 100 == 0):
                    save_position_countries()
            except ValueError:                
                print("get_country error", ValueError)
    if(pos in mapPositionCountries):
        return mapPositionCountries[pos]
    print("### get_country  : country not found for position ", pos, " (maybe in the sea ...)")
    return ""


""" Récupération des données d'une espèce à partir du contenu du fichier csv """
def clean_dataset(dataset, specie_id):
    
    # Table des fréquences par année et position géographique et espèce
    frequencies_dict = {}

    for data in dataset.values:

        if invalide_year(data): continue
            
        # Clé d'une donnée élémentaire : année + position géogrpahique + identifiant de l'espèce
        key = '{} {} {} {}'.format(int(data[0]), data[1], data[2], specie_id)

        # Mise à jour de la fréquence associé à la clé
        if key in frequencies_dict.keys():
            # Clé déjà rencontrée dans le csv : on incrémente la fréquence associée
            frequencies_dict[key] += 1

        else: frequencies_dict[key] = 1

    frequencies = []

    for freq in frequencies_dict.keys():
        k = freq.split(' ')
        country = get_country(k)
        k.append(country)
        k.append(frequencies_dict[freq])
        frequencies.append(k)        
        #print(k)
    return frequencies
    # frequencies = pd.DataFrame(frequencies, columns=['Year', 'Latitude', 'Longitude', 'SpecieId', 'Frequency'])

# %%
mapPositionCountries = load_position_countries()


data_sources = get_all_data_sources()
dataset = fetch_all_dataset(data_sources)


dataset.to_csv('bombus_terrestris_freqs.csv.gz', index=False, compression='gzip')
with open('data_sources.json', 'w+') as output_file:
    json.dump(data_sources, output_file)
print('finished download')
# Out:
# load_position_countries map size =  16795
# ------ finished Bombus (Alpigenobombus) wurflenii id 1 ---------
# ------ finished Bombus (Alpinobombus) alpinus id 2 ---------
# ------ finished Bombus (Alpinobombus) balteatus id 3 ---------
# ------ finished Bombus (Alpinobombus) hyperboreus id 4 ---------
# ------ finished Bombus (Alpinobombus) polaris id 5 ---------
# ------ finished Bombus (Bombus) cryptarum id 6 ---------
# ### get_country  : country not found for position  49.90824,-4.81055  (maybe in the sea ...)
# ### get_country  : country not found for position  49.88551,-5.89353  (maybe in the sea ...)
# ### get_country  : country not found for position  50.09207,-4.53785  (maybe in the sea ...)
# ### get_country  : country not found for position  41.81879,50.15716  (maybe in the sea ...)
# ### get_country  : country not found for position  43.58747,35.84903  (maybe in the sea ...)
# ### get_country  : country not found for position  44.15164,37.374390000000005  (maybe in the sea ...)
# ### get_country  : country not found for position  39.65975,50.88343  (maybe in the sea ...)
# ### get_country  : country not found for position  55.84713000000001,-1.56256  (maybe in the sea ...)
# ### get_country  : country not found for position  54.94,-0.9706299999999999  (maybe in the sea ...)
# ### get_country  : country not found for position  57.284119999999994,-1.507  (maybe in the sea ...)
# ### get_country  : country not found for position  57.459309999999995,-1.16646  (maybe in the sea ...)
# ### get_country  : country not found for position  55.11962,-0.9615299999999999  (maybe in the sea ...)
# ### get_country  : country not found for position  57.104519999999994,-1.51423  (maybe in the sea ...)
# ### get_country  : country not found for position  57.10017,-1.18423  (maybe in the sea ...)
# ### get_country  : country not found for position  58.011469999999996,-2.8307700000000002  (maybe in the sea ...)
# ### get_country  : country not found for position  55.842980000000004,-1.24328  (maybe in the sea ...)
# ### get_country  : country not found for position  54.05347,-4.06928  (maybe in the sea ...)
# ### get_country  : country not found for position  58.011469999999996,-3.1692299999999998  (maybe in the sea ...)
# ### get_country  : country not found for position  58.010569999999994,-2.49231  (maybe in the sea ...)
# ### get_country  : country not found for position  57.45403,-0.83334  (maybe in the sea ...)
# ### get_country  : country not found for position  58.1902,-2.48975  (maybe in the sea ...)
# ### get_country  : country not found for position  57.63887,-1.15741  (maybe in the sea ...)
# ### get_country  : country not found for position  58.368,-2.14531  (maybe in the sea ...)
# ### get_country  : country not found for position  54.0558,-3.76381  (maybe in the sea ...)
# ### get_country  : country not found for position  58.36983000000001,-2.48716  (maybe in the sea ...)
# ### get_country  : country not found for position  58.54761,-2.14094  (maybe in the sea ...)
# ### get_country  : country not found for position  58.72721,-2.13652  (maybe in the sea ...)
# ### get_country  : country not found for position  58.54486,-1.79739  (maybe in the sea ...)
# ### get_country  : country not found for position  56.20976999999999,-1.87148  (maybe in the sea ...)
# ### get_country  : country not found for position  56.02676999999999,-1.55589  (maybe in the sea ...)
# ### get_country  : country not found for position  55.66336,-1.25134  (maybe in the sea ...)
# ### get_country  : country not found for position  56.56908000000001,-1.8608  (maybe in the sea ...)
# ### get_country  : country not found for position  54.23554,-3.7671300000000003  (maybe in the sea ...)
# ### get_country  : country not found for position  56.389430000000004,-1.86617  (maybe in the sea ...)
# ### get_country  : country not found for position  57.46371,19.49969  (maybe in the sea ...)
# ------ finished Bombus (Bombus) lucorum id 7 ---------
# ### get_country  : country not found for position  55.29354,12.63759  (maybe in the sea ...)
# ### get_country  : country not found for position  54.03021,6.40439  (maybe in the sea ...)
# ------ finished Bombus (Bombus) magnus id 8 ---------
# ------ finished Bombus (Bombus) patagiatus id 9 ---------
# ### get_country  : country not found for position  65.0,22.90866  (maybe in the sea ...)
# ### get_country  : country not found for position  64.11134,22.026310000000002  (maybe in the sea ...)
# ### get_country  : country not found for position  64.64964,22.04659  (maybe in the sea ...)
# ### get_country  : country not found for position  63.75473,21.608  (maybe in the sea ...)
# ### get_country  : country not found for position  62.476769999999995,18.47818  (maybe in the sea ...)
# ### get_country  : country not found for position  62.48324,18.8658  (maybe in the sea ...)
# ### get_country  : country not found for position  64.28728000000001,22.44602  (maybe in the sea ...)
# ------ finished Bombus (Bombus) sporadicus id 10 ---------
# ### get_country  : country not found for position  37.85477,20.204279999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  42.69381,6.43634  (maybe in the sea ...)
# ### get_country  : country not found for position  41.998909999999995,39.845209999999994  (maybe in the sea ...)
# ### get_country  : country not found for position  57.46371,19.49969  (maybe in the sea ...)
# ### get_country  : country not found for position  36.23068,31.998509999999996  (maybe in the sea ...)
# ### get_country  : country not found for position  36.95602,50.887679999999996  (maybe in the sea ...)
# ### get_country  : country not found for position  35.4954,23.0947  (maybe in the sea ...)
# ------ finished Bombus (Bombus) terrestris id 11 ---------
# ------ finished Bombus (Confusibombus) confusus id 12 ---------
# ------ finished Bombus (Cullumanobombus) cullumanus id 13 ---------
# ------ finished Bombus (Cullumanobombus) semenoviellus id 14 ---------
# ------ finished Bombus (Kallobombus) soroeensis id 15 ---------
# ------ finished Bombus (Megabombus) argillaceus id 16 ---------
# ------ finished Bombus (Megabombus) consobrinus id 17 ---------
# ------ finished Bombus (Megabombus) gerstaeckeri id 18 ---------
# ------ finished Bombus (Megabombus) hortorum id 19 ---------
# ------ finished Bombus (Megabombus) portschinsky id 20 ---------
# ------ finished Bombus (Megabombus) reinigiellus id 21 ---------
# ### get_country  : country not found for position  49.90824,-4.81055  (maybe in the sea ...)
# ------ finished Bombus (Megabombus) ruderatus id 22 ---------
# ------ finished Bombus (Megabombus) saltuarius id 23 ---------
# ------ finished Bombus (Melanobombus) alagesianus id 24 ---------
# ------ finished Bombus (Melanobombus) erzurumensis id 25 ---------
# ------ finished Bombus (Melanobombus) incertus id 26 ---------
# ### get_country  : country not found for position  57.46371,19.49969  (maybe in the sea ...)
# ### get_country  : country not found for position  50.07793,-0.6239600000000001  (maybe in the sea ...)
# ------ finished Bombus (Melanobombus) lapidarius id 27 ---------
# ------ finished Bombus (Melanobombus) sichelii id 28 ---------
# ------ finished Bombus (Mendacibombus) handlirschianus id 29 ---------
# ------ finished Bombus (Mendacibombus) mendax id 30 ---------
# ------ finished Bombus (Mendacibombus) shaposhnikovi id 31 ---------
# ------ finished Bombus (Psithyrus) barbutellus id 32 ---------
# ### get_country  : country not found for position  57.46371,19.49969  (maybe in the sea ...)
# ### get_country  : country not found for position  54.41684,15.4623  (maybe in the sea ...)
# ### get_country  : country not found for position  54.95604,15.468470000000002  (maybe in the sea ...)
# ### get_country  : country not found for position  54.41763,15.1541  (maybe in the sea ...)
# ### get_country  : country not found for position  54.59737,15.154779999999999  (maybe in the sea ...)
# ------ finished Bombus (Psithyrus) bohemicus id 33 ---------
# ### get_country  : country not found for position  50.62154,-6.87953  (maybe in the sea ...)
# ------ finished Bombus (Psithyrus) campestris id 34 ---------
# ------ finished Bombus (Psithyrus) flavidus id 35 ---------
# ------ finished Bombus (Psithyrus) norvegicus id 36 ---------
# ------ finished Bombus (Psithyrus) perezi id 37 ---------
# ------ finished Bombus (Psithyrus) quadricolor id 38 ---------
# ------ finished Bombus (Psithyrus) rupestris id 39 ---------
# ### get_country  : country not found for position  56.535880000000006,12.03449  (maybe in the sea ...)
# ### get_country  : country not found for position  58.177519999999994,10.87037  (maybe in the sea ...)
# ------ finished Bombus (Psithyrus) sylvestris id 40 ---------
# ### get_country  : country not found for position  36.9471,52.46001  (maybe in the sea ...)
# ------ finished Bombus (Psithyrus) vestalis id 41 ---------
# ------ finished Bombus (Pyrobombus) brodmannicus id 42 ---------
# ------ finished Bombus (Pyrobombus) cingulatus id 43 ---------
# ------ finished Bombus (Pyrobombus) glacialis id 44 ---------
# ------ finished Bombus (Pyrobombus) haematurus id 45 ---------
# ### get_country  : country not found for position  57.46371,19.49969  (maybe in the sea ...)
# ------ finished Bombus (Pyrobombus) hypnorum id 46 ---------
# ### get_country  : country not found for position  49.90724,-4.81043  (maybe in the sea ...)
# ### get_country  : country not found for position  49.91125,-4.53201  (maybe in the sea ...)
# ### get_country  : country not found for position  54.02906,6.40459  (maybe in the sea ...)
# ------ finished Bombus (Pyrobombus) jonellus id 47 ---------
# ------ finished Bombus (Pyrobombus) lapponicus id 48 ---------
# ------ finished Bombus (Pyrobombus) modestus id 49 ---------
# ### get_country  : country not found for position  54.39996,-5.00251  (maybe in the sea ...)
# ------ finished Bombus (Pyrobombus) monticola id 50 ---------
# ### get_country  : country not found for position  60.16679,26.819809999999997  (maybe in the sea ...)
# ------ finished Bombus (Pyrobombus) pratorum id 51 ---------
# ------ finished Bombus (Pyrobombus) pyrenaeus id 52 ---------
# ------ finished Bombus (Sibiricobombus) niveatus id 53 ---------
# ------ finished Bombus (Sibiricobombus) sulfureus id 54 ---------
# ------ finished Bombus (Subterraneobombus) distinguendus id 55 ---------
# ------ finished Bombus (Subterraneobombus) fragrans id 56 ---------
# ------ finished Bombus (Subterraneobombus) melanurus id 57 ---------
# ------ finished Bombus (Subterraneobombus) subterraneus id 58 ---------
# ------ finished Bombus (Thoracobombus) armeniacus id 59 ---------
# ------ finished Bombus (Thoracobombus) brodmanni id 60 ---------
# ------ finished Bombus (Thoracobombus) deuteronymus id 61 ---------
# ### get_country  : country not found for position  49.90724,-4.81043  (maybe in the sea ...)
# ------ finished Bombus (Thoracobombus) humilis id 62 ---------
# ------ finished Bombus (Thoracobombus) inexspectatus id 63 ---------
# ------ finished Bombus (Thoracobombus) laesus id 64 ---------
# ------ finished Bombus (Thoracobombus) mesomelas id 65 ---------
# ------ finished Bombus (Thoracobombus) mlokosievitzii id 66 ---------
# ------ finished Bombus (Thoracobombus) mocsaryi id 67 ---------
# ------ finished Bombus (Thoracobombus) mucidus id 68 ---------
# ### get_country  : country not found for position  53.32207,1.04833  (maybe in the sea ...)
# ### get_country  : country not found for position  56.91415,6.86483  (maybe in the sea ...)
# ------ finished Bombus (Thoracobombus) muscorum id 69 ---------
# ### get_country  : country not found for position  43.619690000000006,-2.13242  (maybe in the sea ...)
# ### get_country  : country not found for position  42.721920000000004,3.3664099999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  43.98252,9.374080000000001  (maybe in the sea ...)
# ### get_country  : country not found for position  43.98252,9.374080000000001  (maybe in the sea ...)
# ### get_country  : country not found for position  56.5563,17.11508  (maybe in the sea ...)
# ### get_country  : country not found for position  57.9791,18.1453  (maybe in the sea ...)
# ### get_country  : country not found for position  58.36983000000001,9.512839999999999  (maybe in the sea ...)
# ### get_country  : country not found for position  43.619690000000006,-2.13242  (maybe in the sea ...)
# ### get_country  : country not found for position  53.49146,-5.5625800000000005  (maybe in the sea ...)
# ### get_country  : country not found for position  52.975019999999994,-10.04247  (maybe in the sea ...)
# ### get_country  : country not found for position  49.90824,-4.81055  (maybe in the sea ...)
# ### get_country  : country not found for position  50.28137,-2.5789299999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  54.40112,-5.002669999999999  (maybe in the sea ...)
# ### get_country  : country not found for position  52.07615,1.9786  (maybe in the sea ...)
# ### get_country  : country not found for position  53.50286,-4.96007  (maybe in the sea ...)
# ### get_country  : country not found for position  53.862190000000005,-4.9768300000000005  (maybe in the sea ...)
# ### get_country  : country not found for position  53.8776,-3.4563300000000003  (maybe in the sea ...)
# ### get_country  : country not found for position  42.721920000000004,3.3664099999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  42.721920000000004,3.3664099999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  49.90824,-1.18945  (maybe in the sea ...)
# ### get_country  : country not found for position  42.721920000000004,3.3664099999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  42.721920000000004,3.3664099999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  43.06366,6.9122  (maybe in the sea ...)
# ### get_country  : country not found for position  42.14837,6.21645  (maybe in the sea ...)
# ### get_country  : country not found for position  42.721920000000004,3.3664099999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  57.9791,18.1453  (maybe in the sea ...)
# ### get_country  : country not found for position  57.467240000000004,19.833  (maybe in the sea ...)
# ### get_country  : country not found for position  56.5563,17.11508  (maybe in the sea ...)
# ### get_country  : country not found for position  52.975019999999994,-10.04247  (maybe in the sea ...)
# ### get_country  : country not found for position  51.705859999999994,-10.88142  (maybe in the sea ...)
# ### get_country  : country not found for position  51.18063,-9.4292  (maybe in the sea ...)
# ### get_country  : country not found for position  52.975019999999994,-10.04247  (maybe in the sea ...)
# ### get_country  : country not found for position  51.18063,-9.4292  (maybe in the sea ...)
# ### get_country  : country not found for position  51.705859999999994,-10.88142  (maybe in the sea ...)
# ### get_country  : country not found for position  51.17714,-10.00141  (maybe in the sea ...)
# ### get_country  : country not found for position  51.18063,-9.4292  (maybe in the sea ...)
# ### get_country  : country not found for position  52.975019999999994,-10.04247  (maybe in the sea ...)
# ### get_country  : country not found for position  52.975019999999994,-10.04247  (maybe in the sea ...)
# ### get_country  : country not found for position  52.95264,-5.5306  (maybe in the sea ...)
# ### get_country  : country not found for position  51.18063,-9.4292  (maybe in the sea ...)
# ### get_country  : country not found for position  52.975019999999994,-10.04247  (maybe in the sea ...)
# ### get_country  : country not found for position  51.17714,-10.00141  (maybe in the sea ...)
# ### get_country  : country not found for position  52.975019999999994,-10.04247  (maybe in the sea ...)
# ### get_country  : country not found for position  51.18063,-9.4292  (maybe in the sea ...)
# ### get_country  : country not found for position  54.40112,-5.002669999999999  (maybe in the sea ...)
# ### get_country  : country not found for position  50.28137,-2.5789299999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  50.28137,-2.5789299999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  50.28137,-2.5789299999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  50.28137,-2.5789299999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  53.862190000000005,-4.9768300000000005  (maybe in the sea ...)
# ### get_country  : country not found for position  53.862190000000005,-4.9768300000000005  (maybe in the sea ...)
# ### get_country  : country not found for position  50.28137,-2.5789299999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  50.28137,-2.5789299999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  52.07615,1.9786  (maybe in the sea ...)
# ### get_country  : country not found for position  56.56908000000001,-1.8608  (maybe in the sea ...)
# ### get_country  : country not found for position  53.862190000000005,-4.9768300000000005  (maybe in the sea ...)
# ### get_country  : country not found for position  53.8776,-3.4563300000000003  (maybe in the sea ...)
# ### get_country  : country not found for position  53.8776,-3.4563300000000003  (maybe in the sea ...)
# ### get_country  : country not found for position  53.50286,-4.96007  (maybe in the sea ...)
# ### get_country  : country not found for position  52.07615,1.9786  (maybe in the sea ...)
# ### get_country  : country not found for position  52.07615,1.9786  (maybe in the sea ...)
# ### get_country  : country not found for position  52.07615,1.9786  (maybe in the sea ...)
# ### get_country  : country not found for position  53.50286,-4.96007  (maybe in the sea ...)
# ### get_country  : country not found for position  52.07615,1.9786  (maybe in the sea ...)
# ### get_country  : country not found for position  50.28137,-2.5789299999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  52.07615,1.9786  (maybe in the sea ...)
# ### get_country  : country not found for position  52.07615,1.9786  (maybe in the sea ...)
# ### get_country  : country not found for position  50.28137,-2.5789299999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  54.40112,-5.002669999999999  (maybe in the sea ...)
# ### get_country  : country not found for position  53.8776,-3.4563300000000003  (maybe in the sea ...)
# ### get_country  : country not found for position  55.646080000000005,-0.2985  (maybe in the sea ...)
# ### get_country  : country not found for position  54.40112,-5.002669999999999  (maybe in the sea ...)
# ### get_country  : country not found for position  49.90824,-4.81055  (maybe in the sea ...)
# ### get_country  : country not found for position  52.07615,1.9786  (maybe in the sea ...)
# ### get_country  : country not found for position  53.8776,-3.4563300000000003  (maybe in the sea ...)
# ### get_country  : country not found for position  53.50286,-4.96007  (maybe in the sea ...)
# ### get_country  : country not found for position  52.07615,1.9786  (maybe in the sea ...)
# ### get_country  : country not found for position  53.50286,-4.96007  (maybe in the sea ...)
# ### get_country  : country not found for position  49.90824,-4.81055  (maybe in the sea ...)
# ### get_country  : country not found for position  52.07615,1.9786  (maybe in the sea ...)
# ### get_country  : country not found for position  50.28137,-2.5789299999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  50.28137,-2.5789299999999997  (maybe in the sea ...)
# ### get_country  : country not found for position  53.8776,-3.4563300000000003  (maybe in the sea ...)
# ### get_country  : country not found for position  56.57334,-8.51173  (maybe in the sea ...)
# ### get_country  : country not found for position  52.975019999999994,-10.04247  (maybe in the sea ...)
# ### get_country  : country not found for position  54.41684,15.4623  (maybe in the sea ...)
# ### get_country  : country not found for position  56.5563,17.11508  (maybe in the sea ...)
# ### get_country  : country not found for position  56.5563,17.11508  (maybe in the sea ...)
# ### get_country  : country not found for position  56.5563,17.11508  (maybe in the sea ...)
# ### get_country  : country not found for position  56.5563,17.11508  (maybe in the sea ...)
# ### get_country  : country not found for position  56.5563,17.11508  (maybe in the sea ...)
# ### get_country  : country not found for position  56.5563,17.11508  (maybe in the sea ...)
# ### get_country  : country not found for position  51.18063,-9.4292  (maybe in the sea ...)
# ### get_country  : country not found for position  51.705859999999994,-10.88142  (maybe in the sea ...)
# ### get_country  : country not found for position  57.9791,18.1453  (maybe in the sea ...)
# ### get_country  : country not found for position  51.18063,-9.4292  (maybe in the sea ...)
# ------ finished Bombus (Thoracobombus) pascuorum id 70 ---------
# ------ finished Bombus (Thoracobombus) pereziellus id 71 ---------
# ------ finished Bombus (Thoracobombus) persicus id 72 ---------
# ------ finished Bombus (Thoracobombus) pomorum id 73 ---------
# ------ finished Bombus (Thoracobombus) ruderarius id 74 ---------
# ------ finished Bombus (Thoracobombus) schrencki id 75 ---------
# ### get_country  : country not found for position  42.68184,5.96579  (maybe in the sea ...)
# ------ finished Bombus (Thoracobombus) sylvarum id 76 ---------
# ------ finished Bombus (Thoracobombus) velox id 77 ---------
# ### get_country  : country not found for position  54.595,15.77387  (maybe in the sea ...)
# ### get_country  : country not found for position  54.77711,14.844529999999999  (maybe in the sea ...)
# ### get_country  : country not found for position  54.77711,14.844529999999999  (maybe in the sea ...)
# ### get_country  : country not found for position  54.59737,15.154779999999999  (maybe in the sea ...)
# ------ finished Bombus (Thoracobombus) veteranus id 78 ---------
# ------ finished Bombus (Thoracobombus) zonatus id 79 ---------
# finished download
